# %%
import pandas as pd
df=pd.read_csv("E:\\Data Science\\py-master\\pandas\\6_handling_missing_data_replace\\weather_data.csv",parse_dates=["day"])
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %%
df=pd.read_csv("E:\\Data Science\\py-master\\pandas\\6_handling_missing_data_replace\\weather_data.csv",na_values=['not available','n.a.',-99999,0])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
new_df=df.fillna(0)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          0.0        7.0  Sunny
# 2  1/3/2017         28.0        0.0   Snow
# 3  1/4/2017          0.0        7.0      0
# 4  1/5/2017         32.0        0.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new_df=df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':'no event'
})
new_df
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017         32.0        6.0      Rain
# 1  1/2/2017          0.0        7.0     Sunny
# 2  1/3/2017         28.0        0.0      Snow
# 3  1/4/2017          0.0        7.0  no event
# 4  1/5/2017         32.0        0.0      Rain
# 5  1/6/2017         31.0        2.0     Sunny
# 6  1/6/2017         34.0        5.0  no event

# %%
new_df=df.fillna(method='ffill')
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         32.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         28.0        7.0   Snow
# 4  1/5/2017         32.0        7.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0  Sunny

# %%
new_df=df.fillna(method='ffill',axis='columns')
new_df
# Out:
#         day temperature windspeed  event
# 0  1/1/2017        32.0       6.0   Rain
# 1  1/2/2017    1/2/2017       7.0  Sunny
# 2  1/3/2017        28.0      28.0   Snow
# 3  1/4/2017    1/4/2017       7.0    7.0
# 4  1/5/2017        32.0      32.0   Rain
# 5  1/6/2017        31.0       2.0  Sunny
# 6  1/6/2017        34.0       5.0    5.0

# %%
new_df=df.fillna(method='ffill',limit=1)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         32.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         28.0        7.0   Snow
# 4  1/5/2017         32.0        7.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0  Sunny

# %%
new_df=df.fillna(method='ffill')
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         32.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         28.0        7.0   Snow
# 4  1/5/2017         32.0        7.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0  Sunny

# %%
new_df=df.interpolate(method="time")
new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12756/4019282522.py in <module>
# ----> 1 new_df=df.interpolate(method="time")
#       2 new_df
#
# ~\phython software\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\phython software\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10710         **kwargs,
#   10711     ) -> DataFrame | None:
# > 10712         return super().interpolate(
#   10713             method,
#   10714             axis,
#
# ...

# %%
new_df=df.dropna()
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny

# %%
new_df=df.dropna(how="all")
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
new_df=df.dropna(thresh=2)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
dt=pd.date_range("01-01-2017","01-11-2017")
idx=pd.DatetimeIndex(dt)
df=df.reindex(idx)
df
# Out:
#             day  temperature  windspeed event
# 2017-01-01  NaN          NaN        NaN   NaN
# 2017-01-02  NaN          NaN        NaN   NaN
# 2017-01-03  NaN          NaN        NaN   NaN
# 2017-01-04  NaN          NaN        NaN   NaN
# 2017-01-05  NaN          NaN        NaN   NaN
# 2017-01-06  NaN          NaN        NaN   NaN
# 2017-01-07  NaN          NaN        NaN   NaN
# 2017-01-08  NaN          NaN        NaN   NaN
# 2017-01-09  NaN          NaN        NaN   NaN
# 2017-01-10  NaN          NaN        NaN   NaN
# 2017-01-11  NaN          NaN        NaN   NaN
